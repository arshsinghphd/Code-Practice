# %% [markdown]
# #### https://www.hackerrank.com/challenges/encryption/problem

# %%
'''
Started at 3:00 pm
Stopped at 3:10 pm
10
Restarted at 3:22 pm
Stopped at 3:40 pm
30
Restarted at 4:00 pm
Stopped at 4:15 pm
45
Restarted at 4:25 pm
Stopped at 5:00 pm
80
Restarted at 6:00 pm
Stopped at 6:30 pm
120
---
2 hrs or so
'''
# Out:
# '\nStarted at 3:00 pm\nStopped at 3:10 pm\nRestarted at 3:22 pm\nStopped at 3:40 pm\nRestarted at 4:00 pm\nStopped at 4:15 pm\nRestarted at 4:25 pm\nStopped at \n'

# %%
s=input()
# Out:
# chillout

# %%
def encryption(s):
    # remove all spaces, this may be a
    raw=s.replace(" ","")
    
    # decide the n_row and n_col
    # fix this part to choose n_row and n_col to min(n_row*n_col)
    l=len(raw)
    n_col=0
    n_row=0
    # special case of perfect square
    if (int(l**.5))**2==l:
        n_col=int(l**.5)
        n_row=int(l**.5)
    else:
        n_row=int(l**.5)
        n_col=int(l**.5)+1
    # check to see if the matrix will fill all raw
        if n_row*n_col<l:
            n_row+=1
    size=n_col*n_row
    m=['']*size
    for i in range(l):
        m[i]=raw[i]
        
    result=''
    for i in range(n_col):
        s=''
        for j in range(n_row):
            if m[i+n_col*j]!=' ':
                s+=m[i+n_col*j]
        result+=s
        result+=' '
    return result

# %%
print(encryption(s))
# Out:
# clu hlt io
